# %% [markdown]
# # dataset

# %%
import numpy as np
import pandas as pd

# %%
data = np.load("MIXEDR4_114dsei00/MIXEDR4_114dsei00.npy")
real = data[:, 0, :, :]
imag = data[:, 1, :, :]

df = pd.DataFrame({
    "real": list(real),   # each element is a (13,32) ndarray
    "imag": list(imag)
})

# %%
df.head()
# Out:
#                                                 real  \
# 0  [[0.21466087, -0.17984532, 0.015546491, -0.122...
# 1  [[0.15750813, -0.030407492, 0.17322381, 0.0119...
# 2  [[0.21564163, -0.053608317, 0.15069366, 0.1825...
# 3  [[0.085004166, -0.017324746, 0.042449176, -0.0...
# 4  [[0.24709222, -0.23738584, 0.13368812, -0.1340...
#
#                                                 imag
# 0  [[0.0, 0.12983207, 0.17724419, -0.1369922, 0.0...
# 1  [[0.0, -0.18515831, 0.040723186, -0.19621779, ...
# 2  [[0.0, -0.17658131, 0.22834276, -0.18058468, 0...
# 3  [[0.0, 0.04596916, -0.007453814, 0.0012580045,...
# 4  [[0.0, -0.0048156795, -0.19413038, 0.19853236,...

# %%
data.shape
# Out:
# (500000, 2, 13, 32)

# %%
import numpy as np
import torch

class CSIDataCollater:
    def __init__(self, batch_size=200, snr_low=-10.0, snr_high=10.0):
        self.batch_size = batch_size
        self.snr_low = snr_low
        self.snr_high = snr_high
        
        # Define indices based on the provided image distribution
        self.indices_map = {
            "train": list(range(0, 400000)),
            "val": list(range(400000, 450000)),
            "test": list(range(450000, 500000))
        }

    def __call__(self, data_array, mode="train"):
        """
        data_array: numpy array of shape (500000, 2, 13, 32)
        mode: "train", "val", or "test"
        """
        # 1. Get the relevant range of indices for the current mode
        possible_indices = self.indices_map[mode]
        
        # 2. Randomly sample indices for the batch
        selected_indices = np.random.choice(possible_indices, self.batch_size, replace=False)
        batch_csi = data_array[selected_indices]  # Shape: (B, 2, 13, 32)
        
        # 3. Permute to (B, 13, 32, 2)
        batch_csi = np.transpose(batch_csi, (0, 2, 3, 1))
        
        # 4. Sample SNR from uniform distribution [-10, 10] dB [cite: 445]
        batch_snr = np.random.uniform(self.snr_low, self.snr_high, (self.batch_size, 1))
        
        return torch.from_numpy(batch_csi).float(), torch.from_numpy(batch_snr).float()

# %%
# Usage
collater = CSIDataCollater()
csi_batch, snr_batch = collater(data)

# %%
csi_batch.shape, snr_batch.shape
# Out:
# (torch.Size([200, 13, 32, 2]), torch.Size([200, 1]))

# %% [markdown]
# ## AF module

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class AFModule(nn.Module):
    def __init__(self, channels, reduction_ratio=2):
        """
        AF Module (Attention Feature Module)
        Args:
            channels: Number of input feature channels (C).
            reduction_ratio: Ratio for the hidden layer size in the MLP. 
                             Since channels are small (16), we can use a small ratio or no reduction.
        """
        super(AFModule, self).__init__()
        
        # 1. Context Extraction is handled in forward (Global Avg Pooling + Concat)
        
        # 2. Factor Prediction (MLP)
        # Input size = Channels (from Global Avg Pool) + 1 (from SNR mu)
        input_dim = channels + 1 
        hidden_dim = max(channels // reduction_ratio, 1) # Ensure hidden dim is at least 1
        
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, channels)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, snr):
        """
        Args:
            x: Feature map tensor of shape (Batch, Channels, Height, Width)
            snr: Signal-to-Noise Ratio tensor of shape (Batch, 1)
        """
        batch, channels, height, width = x.size()

        # --- 1. Context Extraction ---
        # Global Average Pooling: Average over H and W dimensions -> (Batch, Channels)
        global_feat = F.avg_pool2d(x, (height, width)).view(batch, channels)
        
        # Concatenation: Combine global features with SNR
        # global_feat: (B, C), snr: (B, 1) -> context: (B, C+1)
        context = torch.cat([global_feat, snr], dim=1)

        # --- 2. Factor Prediction ---
        # Pass through MLP to get scale factors
        out = self.fc1(context)
        out = self.relu(out)
        out = self.fc2(out)
        scale_factors = self.sigmoid(out) # Shape: (Batch, Channels)

        # --- 3. Feature Recalibration ---
        # Reshape scale factors to (Batch, Channels, 1, 1) for broadcasting
        scale_factors = scale_factors.view(batch, channels, 1, 1)
        
        # Element-wise multiplication
        out = x * scale_factors
        
        return out

# %% [markdown]
# ## ATN module

# %%
class ATN(nn.Module):
    def __init__(self):
        super(ATN, self).__init__()
        
        # --- Block 1 ---
        # Conv: 2 -> 16, Kernel (3,3), Stride (2,1), Padding (1,1)
        self.conv1 = nn.Conv2d(in_channels=2, out_channels=16, 
                               kernel_size=(3, 3), stride=(2, 1), padding=(1, 1))
        self.bn1 = nn.BatchNorm2d(16)
        self.prelu1 = nn.PReLU()
        self.af1 = AFModule(channels=16)

        # --- Block 2 ---
        # Conv: 16 -> 16, Kernel (3,3), Stride (2,1), Padding (1,1)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=16, 
                               kernel_size=(3, 3), stride=(2, 1), padding=(1, 1))
        self.bn2 = nn.BatchNorm2d(16)
        self.prelu2 = nn.PReLU()
        self.af2 = AFModule(channels=16)

        # --- Block 3 ---
        # Conv: 16 -> 2, Kernel (3,3), Stride (2,1), Padding (1,1)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=2, 
                               kernel_size=(3, 3), stride=(2, 1), padding=(1, 1))
        self.bn3 = nn.BatchNorm2d(2)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, snr):
        """
        Args:
            x: Input tensor of shape (Batch, Height, Width, Channels) -> (B, 13, 32, 2)
            snr: SNR value (Batch, 1)
        """
        # Permute input to match PyTorch convention (B, C, H, W)
        # Input (B, 13, 32, 2) -> (B, 2, 13, 32)
        x = x.permute(0, 3, 1, 2)
        
        # --- Block 1 ---
        x = self.conv1(x)       # (B, 2, 13, 32) -> (B, 16, 7, 32)
        x = self.bn1(x)
        x = self.prelu1(x)
        x = self.af1(x, snr)    # AF Module uses 'snr'

        # --- Block 2 ---
        x = self.conv2(x)       # (B, 16, 7, 32) -> (B, 16, 4, 32)
        x = self.bn2(x)
        x = self.prelu2(x)
        x = self.af2(x, snr)    # AF Module uses 'snr'

        # --- Block 3 ---
        x = self.conv3(x)       # (B, 16, 4, 32) -> (B, 2, 2, 32)
        x = self.bn3(x)
        x = self.sigmoid(x)

        # Permute back to user notation (B, H, W, C)
        # Output (B, 2, 2, 32) -> (B, 2, 32, 2)
        x = x.permute(0, 2, 3, 1)
        
        return x

# %%
if __name__ == "__main__":
    # 1. Setup Input with Batch Size = 200
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    batch_size = 200
    
    # Input format: (Batch, Height, Width, Channels) -> (200, 13, 32, 2)
    input_tensor = csi_batch.to(device)
    
    # 2. Setup SNR (mu)
    # One SNR value per image in the batch -> (200, 1)
    snr_tensor = snr_batch.to(device)

    # 3. Initialize Model
    model = ATN().to(device)

    # 4. Forward Pass
    output_tensor = model(input_tensor, snr_tensor)

    # 5. Print Dimensions
    print("--- Dimension Check ---")
    print(f"Input Shape:  {input_tensor.shape}")  # Expected: (200, 13, 32, 2)
    print(f"Output Shape: {output_tensor.shape}") # Expected: (200, 2, 32, 2)
    
    # Verify exact values
    assert output_tensor.shape == (200, 2, 32, 2), "Dimension mismatch!"
    print("\nSUCCESS: Dimensions match the manual calculation.")
# Out:
# --- Dimension Check ---
# Input Shape:  torch.Size([200, 13, 32, 2])
# Output Shape: torch.Size([200, 2, 32, 2])
#
# SUCCESS: Dimensions match the manual calculation.

# %% [markdown]
# ## encoder

# %%
class CsiNetPlusEncoderWithAF(nn.Module):
    def __init__(self, compression_ratio=16):
        """
        ADJSCC-CSI Encoder with Attention Feature (AF) Modules.
        Input shape: [B, 2, 32, 2]
        """
        super(CsiNetPlusEncoderWithAF, self).__init__()
        
        # --- Constants ---
        self.input_channels = 2
        self.height = 32
        self.width = 2
        self.total_elements = self.input_channels * self.height * self.width # 128
        self.M = int(self.total_elements / compression_ratio)
        
        # --- 1. First Convolutional Block ---
        self.conv1 = nn.Conv2d(in_channels=self.input_channels, 
                               out_channels=2, 
                               kernel_size=7, 
                               stride=1, 
                               padding=3)
        self.bn1 = nn.BatchNorm2d(num_features=2)
        self.act1 = nn.LeakyReLU(negative_slope=0.3, inplace=True)
        
        # [NEW] AF Module inserted after activation [cite: 2737, 2803]
        self.af1 = AFModule(channels=2)
        
        # --- 2. Second Convolutional Block ---
        self.conv2 = nn.Conv2d(in_channels=2, 
                               out_channels=2, 
                               kernel_size=7, 
                               stride=1, 
                               padding=3)
        self.bn2 = nn.BatchNorm2d(num_features=2)
        self.act2 = nn.LeakyReLU(negative_slope=0.3, inplace=True)
        
        # [NEW] AF Module inserted after activation [cite: 2737, 2803]
        self.af2 = AFModule(channels=2)
        
        # --- 3. Fully Connected Layer ---
        self.fc = nn.Linear(in_features=self.total_elements, out_features=self.M)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, snr):
        """
        Forward pass with SNR adaption.
        Args:
            x: Input tensor [B, 2, 32, 2]
            snr: SNR value tensor [B, 1] required for AF Modules
        """
        
        # Step 1: First Conv Block + AF Recalibration
        out = self.conv1(x)
        out = self.bn1(out) 
        out = self.act1(out)
        out = self.af1(out, snr) # Apply Attention Feature module [cite: 2737]
        
        # Step 2: Second Conv Block + AF Recalibration
        out = self.conv2(out)
        out = self.bn2(out)
        out = self.act2(out)
        out = self.af2(out, snr) # Apply Attention Feature module [cite: 2737]
        
        # Step 3: Flatten
        out = out.view(out.size(0), -1)
        
        # Step 4: FC Layer + Scaling
        out = self.fc(out)
        out = self.sigmoid(out)
        
        return out

# %%
# --- Verification Example ---
if __name__ == "__main__":
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    B = 200
    
    # Instantiate Modified Encoder
    model = CsiNetPlusEncoderWithAF(compression_ratio=8).to(device)
    
    # Dummy Input [B, 2, 32, 2]
    dummy_input = output_tensor.to(device)

    dummy_snr = snr_batch.to(device)
    
    # Forward Pass with SNR
    output = model(dummy_input, dummy_snr)
    
    print(f"Input Shape: {dummy_input.shape}")
    print(f"SNR Shape: {dummy_snr.shape}")
    print(f"Output Shape: {output.shape}")
    print(f"AF Modules Successfully Integrated.")
# Out:
# Input Shape: torch.Size([200, 2, 32, 2])
# SNR Shape: torch.Size([200, 1])
# Output Shape: torch.Size([200, 16])
# AF Modules Successfully Integrated.

# %%
output[0]
# Out:
# tensor([0.5359, 0.4833, 0.4418, 0.4630, 0.4001, 0.3996, 0.5103, 0.4183, 0.5806,
#         0.4781, 0.4656, 0.4706, 0.5150, 0.5091, 0.5663, 0.5770],
#        device='cuda:0', grad_fn=<SelectBackward0>)

# %% [markdown]
# ## real to complex symbols and power normalization

# %%
import torch

def enc_to_complex_and_normalize(encoder_output):
    """
    Converts real-valued encoder output to complex representation and 
    applies power normalization.

    Args:
        encoder_output (torch.Tensor): Output from encoder with shape [B, 2k] 
                                       (e.g., [B, 16]).
    
    Returns:
        torch.Tensor: Normalized complex symbols with shape [B, k] (e.g., [B, 8]).
    """
    
    # --- Step 1: Real-to-Complex Conversion [cite: 146, 324] ---
    # The paper mentions combining real values to form complex values.
    # As discussed, we split the [B, 16] vector into two [B, 8] vectors.
    
    # Calculate k (half the dimension of the real vector)
    k = encoder_output.shape[1] // 2 
    
    # Slicing: First k elements = Real (I), Remaining k elements = Imaginary (Q)
    real_part = encoder_output[:, :k]
    imag_part = encoder_output[:, k:]
    
    # Create the complex tensor s
    s = torch.complex(real_part, imag_part)
    
    # --- Step 2: Power Normalization  ---
    # Constraint: (1/k) * E(s * s*) = 1
    # We normalize by the square root of the average power over the batch 
    # to satisfy the expectation E[...] = 1.
    
    # Calculate the average power of the current batch
    # |s|^2 = real^2 + imag^2
    batch_avg_power = torch.mean(s.abs().square())
    
    # Normalize the complex vector s
    # We divide by sqrt(P_avg) so that the new P_avg becomes 1
    s_normalized = s / torch.sqrt(batch_avg_power)
    
    return s_normalized

# %%
encoder_output = output

# Apply conversion and normalization
complex_symbols = enc_to_complex_and_normalize(encoder_output)

print("Input Shape:      ", encoder_output.shape)  # Should be [4, 16]
print("Output Shape:     ", complex_symbols.shape) # Should be [4, 8]
print("Output Data Type: ", complex_symbols.dtype) # Should be complex64

# --- Verification of Power Constraint ---
# The mean power of the output should be approximately 1.0
actual_power = torch.mean(complex_symbols.abs().square())
print(f"Average Power:     {actual_power.item():.4f}")
# Out:
# Input Shape:       torch.Size([200, 16])
# Output Shape:      torch.Size([200, 8])
# Output Data Type:  torch.complex64
# Average Power:     1.0000

# %%
complex_symbols[0]
# Out:
# tensor([0.7611+0.8246j, 0.6863+0.6791j, 0.6274+0.6612j, 0.6576+0.6683j,
#         0.5682+0.7314j, 0.5676+0.7231j, 0.7247+0.8042j, 0.5941+0.8195j],
#        device='cuda:0', grad_fn=<SelectBackward0>)

# %% [markdown]
# ## modeling channel

# %%
import torch
import torch.nn as nn

class WirelessChannelSimulator(nn.Module):
    def __init__(self, num_bs_antennas=32):
        """
        Simulates the wireless channel for CSI feedback as described in the paper.
        
        Args:
            num_bs_antennas (int): Nt, number of antennas at the BS. 
                                   Paper uses Nt=32 in experiments[cite: 406].
        """
        super().__init__()
        self.Nt = num_bs_antennas

    def forward(self, s, snr_db):
        """
        Args:
            s (torch.Tensor): Complex symbols of shape [B, K]. 
                              Represents the encoded vector 's' mapped to subcarriers.
                              **Assumes Power Normalization is already applied.**
            snr_db (torch.Tensor): Signal-to-Noise Ratio in dB for each example.
                                   Shape: [B, 1].

        Returns:
            torch.Tensor: Recovered symbols s_hat of shape [B, K] after MRC.
        """
        batch_size, k = s.shape
        device = s.device

        # 1. Generate Uplink Channel Coefficients (h_u)
        # Using Rayleigh Fading h_u ~ CN(0, I) as a proxy for the paper's channel.
        # Shape: [B, K, Nt]
        h_u_real = torch.randn(batch_size, k, self.Nt, device=device)
        h_u_imag = torch.randn(batch_size, k, self.Nt, device=device)
        # Normalize so variance is 1 (standard complex normal)
        h_u = torch.complex(h_u_real, h_u_imag) * (1/torch.sqrt(torch.tensor(2.0)))

        # 2. Generate AWGN Noise (z)
        # y_i = h_u^i * s_i + z_i (Eq. 2)
        # Calculate noise deviation per batch item based on its specific SNR
        # P_signal = 1 (assumed normalized)
        # P_noise = 1 / 10^(SNR/10)
        snr_linear = 10 ** (snr_db / 10.0) # Shape: [B, 1]
        noise_power = 1.0 / snr_linear
        noise_std = torch.sqrt(noise_power / 2.0) # /2 for splitting into real/imag

        # Reshape noise_std for broadcasting: [B, 1] -> [B, 1, 1]
        # This allows multiplication with noise tensor of shape [B, K, Nt]
        noise_std = noise_std.unsqueeze(-1)

        # Generate standard noise and scale by calculated std
        z_real = torch.randn(batch_size, k, self.Nt, device=device) * noise_std
        z_imag = torch.randn(batch_size, k, self.Nt, device=device) * noise_std
        z = torch.complex(z_real, z_imag) # Shape: [B, K, Nt]

        # 3. Transmission (Eq. 2)
        # Expand s to broadcast: [B, K] -> [B, K, 1] for multiplication with [B, K, Nt] channel
        s_expanded = s.unsqueeze(-1) 
        
        # Received signal y at BS antennas
        y = h_u * s_expanded + z  # Shape: [B, K, Nt]

        # 4. Maximum Ratio Combining (MRC) at BS (Eq. 3) [cite: 196-199]
        # The combining vector w_i = h_u^i / ||h_u^i||_2
        # Norm over antenna dimension (Nt)
        h_norm = torch.norm(h_u, dim=2, keepdim=True) # Shape: [B, K, 1]
        
        # Avoid division by zero
        h_norm = torch.clamp(h_norm, min=1e-8)
        
        w = h_u / h_norm # Shape: [B, K, Nt]

        # s_hat_i = w_i^H * y_i
        # Sum over antennas (dim=2)
        s_hat = torch.sum(torch.conj(w) * y, dim=2) # Shape: [B, K]

        return s_hat

# %%
# --- Usage Example ---
if __name__ == "__main__":

    Nt = 32 
    
    input_symbols = complex_symbols

    snr_db = snr_batch

    # Initialize Simulator
    channel_sim = WirelessChannelSimulator(num_bs_antennas=Nt).to(device)

    # Simulate Transmission
    received_symbols = channel_sim(input_symbols.to(device), snr_db.to(device))

    print(f"Input Symbols Shape: {input_symbols.shape}") # [B, K]
    print(f"SNR Shape: {snr_db.shape}")                 # [B, 1]
    print(f"Output Symbols Shape: {received_symbols.shape}") # [B, K]
# Out:
# Input Symbols Shape: torch.Size([200, 8])
# SNR Shape: torch.Size([200, 1])
# Output Symbols Shape: torch.Size([200, 8])

# %% [markdown]
# ## C2R

# %%
import torch
import torch.nn as nn

class ComplexToReal(nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, s_hat):
        """
        Converts complex symbols to real-valued vector by concatenating 
        real and imaginary parts.
        
        Args:
            s_hat (torch.Tensor): Complex tensor of shape [B, K].
                                  Example: [B, 8]
        
        Returns:
            torch.Tensor: Real tensor of shape [B, 2*K].
                          Example: [B, 16]
                          Structure: [Real_1...Real_K, Imag_1...Imag_K]
        """
        # Extract real and imaginary parts
        # Shape of each: [B, K]
        real_part = s_hat.real
        imag_part = s_hat.imag
        
        # Concatenate along the feature dimension (dim=1)
        # Resulting shape: [B, K + K] -> [B, 2K]
        c_hat = torch.cat((real_part, imag_part), dim=1)
        
        return c_hat

# %%
if __name__ == "__main__":

    s_hat = received_symbols
    
    # Initialize the converter
    c2r = ComplexToReal()
    
    # Perform conversion
    c_hat = c2r(s_hat)
    
    print(f"Input Shape (Complex): {s_hat.shape}")  # [2, 8]
    print(f"Output Shape (Real):   {c_hat.shape}")  # [2, 16]
# Out:
# Input Shape (Complex): torch.Size([200, 8])
# Output Shape (Real):   torch.Size([200, 16])

# %% [markdown]
# ## Decoder

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class ModifiedRefineNetBlock(nn.Module):
    """
    Modified RefineNet Block with AF Modules.
    Paper Rule: AF Module is placed after each main layer[cite: 348, 366].
    """
    def __init__(self, channels=2):
        super(ModifiedRefineNetBlock, self).__init__()
        
        # --- Layer 1 ---
        # Main Layer: Conv 7x7 -> BN -> LeakyReLU
        self.conv1 = nn.Conv2d(in_channels=channels, out_channels=8, 
                               kernel_size=7, padding=3)
        self.bn1 = nn.BatchNorm2d(8)
        # AF Module 1 (Input channels: 8)
        self.af1 = AFModule(8)
        
        # --- Layer 2 ---
        # Main Layer: Conv 5x5 -> BN -> LeakyReLU
        self.conv2 = nn.Conv2d(in_channels=8, out_channels=16, 
                               kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm2d(16)
        # AF Module 2 (Input channels: 16)
        self.af2 = AFModule(16)
        
        # --- Layer 3 ---
        # Main Layer: Conv 3x3 -> BN -> Tanh
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=channels, 
                               kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(channels)
        # AF Module 3 (Input channels: original 'channels', e.g., 2)
        self.af3 = AFModule(channels)
        
    def forward(self, x, snr):
        identity = x
        
        # Block 1
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.leaky_relu(out, negative_slope=0.3)
        out = self.af1(out, snr) # Apply AF
        
        # Block 2
        out = self.conv2(out)
        out = self.bn2(out)
        out = F.leaky_relu(out, negative_slope=0.3)
        out = self.af2(out, snr) # Apply AF
        
        # Block 3
        out = self.conv3(out)
        out = self.bn3(out)
        out = torch.tanh(out)
        out = self.af3(out, snr) # Apply AF
        
        # Residual
        out = identity + out
        out = F.relu(out)
        
        return out

class CsiNetPlusDecoder(nn.Module):
    def __init__(self, input_dim=16, height=32, width=2, channels=2, num_blocks=2):
        super(CsiNetPlusDecoder, self).__init__()
        
        self.height = height
        self.width = width
        self.channels = channels
        self.flattened_dim = height * width * channels 
        
        # 1. FC Layer
        self.fc = nn.Linear(input_dim, self.flattened_dim)
        
        # 2. Initial Refinement
        self.initial_conv = nn.Conv2d(in_channels=channels, out_channels=channels, 
                                      kernel_size=7, padding=3)
        self.initial_bn = nn.BatchNorm2d(channels)
        # AF Module for Initial Refinement
        self.initial_af = AFModule(channels)
        
        # 3. RefineNet Chain
        # Use ModuleList instead of Sequential to pass 'snr' in the loop
        self.refinenet_chain = nn.ModuleList(
            [ModifiedRefineNetBlock(channels) for _ in range(num_blocks)]
        )
        
    def forward(self, x, snr):
        """
        Args:
            x: Input vector [Batch, input_dim]
            snr: SNR vector [Batch, 1]
        """
        # FC Layer
        x = self.fc(x)
        x = x.view(-1, self.channels, self.height, self.width)
        
        # Initial Refinement with AF
        x = self.initial_conv(x)
        x = self.initial_bn(x)
        x = torch.sigmoid(x)
        x = self.initial_af(x, snr) # Apply AF [cite: 366]
        
        # RefineNet Chain with AF (Passing SNR to each block)
        for block in self.refinenet_chain:
            x = block(x, snr)
        
        return x

# %%
model = CsiNetPlusDecoder().to(device)

# 3. Create Dummy Data
# x: The compressed codeword vector
x = c_hat

# snr: The Signal-to-Noise Ratio for each sample in the batch
# Shape must be (Batch, 1) as expected by AFModule
snr = snr_batch

# 4. Forward Pass
output_decoder = model(x.to(device), snr.to(device))

# 5. Check Output
print("Input shape: ", x.shape)
print("SNR shape:   ", snr.shape)
print("Output shape:", output_decoder.shape) 
# Expected Output shape: (32, 2, 32, 2) matches (Batch, Channels, Height, Width)
# Out:
# Input shape:  torch.Size([200, 16])
# SNR shape:    torch.Size([200, 1])
# Output shape: torch.Size([200, 2, 32, 2])

# %% [markdown]
# ## STN

# %%
class STN(nn.Module):
    def __init__(self):
        super(STN, self).__init__()
        
        # Configuration for preserving spatial size (32, 2) -> (32, 2)
        # Kernel: (3, 3)
        # Stride: (1, 1) (No spatial upscaling required)
        # Padding: (1, 1) (To maintain input size)
        
        # Layer 1: Input Channels 2 -> Hidden Channels 16
        self.trans_conv1 = nn.ConvTranspose2d(
            in_channels=2, out_channels=16, 
            kernel_size=(3, 3), stride=(1, 1), 
            padding=(1, 1)
        )
        self.bn1 = nn.BatchNorm2d(16)
        self.prelu1 = nn.PReLU(num_parameters=16) 
        self.af1 = AFModule(channels=16)

        # Layer 2: Hidden Channels 16 -> Hidden Channels 16
        self.trans_conv2 = nn.ConvTranspose2d(
            in_channels=16, out_channels=16, 
            kernel_size=(3, 3), stride=(1, 1), 
            padding=(1, 1)
        )
        self.bn2 = nn.BatchNorm2d(16)
        self.prelu2 = nn.PReLU(num_parameters=16)
        self.af2 = AFModule(channels=16)

        # Layer 3: Hidden Channels 16 -> Output Channels 13 (Subcarriers)
        self.trans_conv3 = nn.ConvTranspose2d(
            in_channels=16, out_channels=13, 
            kernel_size=(3, 3), stride=(1, 1), 
            padding=(1, 1)
        )
        self.bn3 = nn.BatchNorm2d(13)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x, snr):
        """
        Args:
            x: Input tensor. Shape (B, 2, 32, 2)
            snr: SNR tensor. Shape (B, 1)
        Returns:
            out: Recovered CSI. Shape (B, 13, 32, 2)
        """
        # Block 1
        out = self.trans_conv1(x)
        out = self.bn1(out)
        out = self.prelu1(out)
        out = self.af1(out, snr)

        # Block 2
        out = self.trans_conv2(out)
        out = self.bn2(out)
        out = self.prelu2(out)
        out = self.af2(out, snr)

        # Block 3
        out = self.trans_conv3(out)
        out = self.bn3(out)
        out = self.sigmoid(out)

        return out

# %%
if __name__ == "__main__":
    batch_size = 8
    # Input shape: (B, 2, 32, 2)
    input_tensor = output_decoder
    snr_tensor = snr_batch

    model = STN().to(device)
    output = model(input_tensor.to(device), snr_tensor.to(device))

    print("Input Shape:", input_tensor.shape)   # Expected: (8, 2, 32, 2)
    print("Output Shape:", output.shape) # Expected: (8, 13, 32, 2)
# Out:
# Input Shape: torch.Size([200, 2, 32, 2])
# Output Shape: torch.Size([200, 13, 32, 2])

# %% [markdown]
# ## training loop

# %%
device
# Out:
# device(type='cuda')

# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau
import time

def calculate_nmse(h_true, h_pred):
    """
    Calculates NMSE in dB as defined in Eq. 22 
    h_true/h_pred shape: [B, 13, 32, 2]
    """
    # Flatten to [Batch, -1] for Euclidean norm calculation
    h_true_flat = h_true.reshape(h_true.size(0), -1)
    h_pred_flat = h_pred.reshape(h_pred.size(0), -1)
    
    # ||H - H_hat||^2 / ||H||^2
    mse = torch.sum((h_true_flat - h_pred_flat)**2, dim=1)
    power = torch.sum(h_true_flat**2, dim=1)
    nmse_linear = torch.mean(mse / power)
    
    return 10 * torch.log10(nmse_linear)

# --- Hyperparameters from Paper ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 200 # [cite: 433]
num_epochs = 500 # [cite: 435]
train_steps = 400000 // batch_size # Based on updated distribution
val_steps = 50000 // batch_size

# Initialize your implemented modules
atn = ATN().to(device)
encoder = CsiNetPlusEncoderWithAF(compression_ratio=8).to(device)
channel_sim = WirelessChannelSimulator(num_bs_antennas=32).to(device)
c2r = ComplexToReal().to(device)
decoder = CsiNetPlusDecoder().to(device)
stn = STN().to(device)

# Combine parameters for global end-to-end training [cite: 93, 396]
all_params = (list(atn.parameters()) + list(encoder.parameters()) + 
              list(decoder.parameters()) + list(stn.parameters()))


optimizer = Adam(all_params, lr=1e-3) # [cite: 433]
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=20, min_lr=1e-4) # [cite: 434, 435]
criterion = nn.MSELoss()
collater = CSIDataCollater(batch_size=batch_size)

# --- 2. Training Loop ---
num_epochs = 500 

for epoch in range(num_epochs):
    start_time = time.time()
    # --- Training Phase ---
    atn.train(); encoder.train(); decoder.train(); stn.train()
    total_train_loss = 0.0
    
    for _ in range(train_steps):
        x_raw, snr_mu = collater(data, mode="train")
        x_raw, snr_mu = x_raw.to(device), snr_mu.to(device)
        
        optimizer.zero_grad()
        # End-to-End Forward Pass
        t = atn(x_raw, snr_mu)
        c = encoder(t, snr_mu)
        s = enc_to_complex_and_normalize(c)
        s_hat = channel_sim(s, snr_mu)
        c_hat = c2r(s_hat)
        t_hat = decoder(c_hat, snr_mu)
        x_hat = stn(t_hat, snr_mu)
        
        loss = criterion(x_hat, x_raw)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

    # --- Validation Phase ---
    atn.eval(); encoder.eval(); decoder.eval(); stn.eval()
    total_val_nmse = 0.0
    
    with torch.no_grad():
        for _ in range(val_steps):
            x_val, snr_val = collater(data, mode="val")
            x_val, snr_val = x_val.to(device), snr_val.to(device)
            
            # Forward Pass
            t = atn(x_val, snr_val)
            c = encoder(t, snr_val)
            s = enc_to_complex_and_normalize(c)
            s_hat = channel_sim(s, snr_val)
            c_hat = c2r(s_hat)
            t_hat = decoder(c_hat, snr_val)
            x_hat = stn(t_hat, snr_val)
            
            total_val_nmse += calculate_nmse(x_val, x_hat).item()

    avg_train_loss = total_train_loss / train_steps
    avg_val_nmse = total_val_nmse / val_steps
    
    # Scheduler step based on validation performance
    scheduler.step(avg_train_loss)
    
    print(f"Epoch [{epoch+1}/{num_epochs}]")
    print(f"Train Loss: {avg_train_loss:.6f} | Val NMSE: {avg_val_nmse:.2f} dB")
    print(f"Current LR: {optimizer.param_groups[0]['lr']}")
    print("-" * 30)
    end_time = time.time()
    print(f"Epoch took {end_time - start_time:.2f} seconds")
# Out:
# Epoch [1/500]
# Train Loss: 0.112597 | Val NMSE: 4.92 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.71 seconds
# Epoch [2/500]
# Train Loss: 0.037160 | Val NMSE: 3.36 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [3/500]
# Train Loss: 0.031679 | Val NMSE: 2.86 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.29 seconds
# Epoch [4/500]
# Train Loss: 0.029454 | Val NMSE: 2.67 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [5/500]
# Train Loss: 0.028532 | Val NMSE: 2.55 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.12 seconds
# Epoch [6/500]
# Train Loss: 0.027630 | Val NMSE: 2.38 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.88 seconds
# Epoch [7/500]
# Train Loss: 0.026306 | Val NMSE: 2.20 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [8/500]
# Train Loss: 0.025787 | Val NMSE: 2.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [9/500]
# Train Loss: 0.025620 | Val NMSE: 2.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.80 seconds
# Epoch [10/500]
# Train Loss: 0.025486 | Val NMSE: 2.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.17 seconds
# Epoch [11/500]
# Train Loss: 0.025400 | Val NMSE: 2.10 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.43 seconds
# Epoch [12/500]
# Train Loss: 0.025321 | Val NMSE: 2.10 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [13/500]
# Train Loss: 0.025269 | Val NMSE: 2.09 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [14/500]
# Train Loss: 0.025221 | Val NMSE: 2.10 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.80 seconds
# Epoch [15/500]
# Train Loss: 0.025190 | Val NMSE: 2.07 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 47.02 seconds
# Epoch [16/500]
# Train Loss: 0.025176 | Val NMSE: 2.08 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.41 seconds
# Epoch [17/500]
# Train Loss: 0.025149 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.08 seconds
# Epoch [18/500]
# Train Loss: 0.025143 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.59 seconds
# Epoch [19/500]
# Train Loss: 0.025118 | Val NMSE: 2.07 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [20/500]
# Train Loss: 0.025121 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.94 seconds
# Epoch [21/500]
# Train Loss: 0.025093 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.89 seconds
# Epoch [22/500]
# Train Loss: 0.025086 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.59 seconds
# Epoch [23/500]
# Train Loss: 0.025082 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.59 seconds
# Epoch [24/500]
# Train Loss: 0.025074 | Val NMSE: 2.06 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.49 seconds
# Epoch [25/500]
# Train Loss: 0.025071 | Val NMSE: 2.05 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.42 seconds
# Epoch [26/500]
# Train Loss: 0.025059 | Val NMSE: 2.08 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 47.46 seconds
# Epoch [27/500]
# Train Loss: 0.025070 | Val NMSE: 2.05 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.39 seconds
# Epoch [28/500]
# Train Loss: 0.025067 | Val NMSE: 2.05 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.02 seconds
# Epoch [29/500]
# Train Loss: 0.025058 | Val NMSE: 2.04 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.91 seconds
# Epoch [30/500]
# Train Loss: 0.016015 | Val NMSE: -1.12 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.84 seconds
# Epoch [31/500]
# Train Loss: 0.012080 | Val NMSE: -1.10 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.41 seconds
# Epoch [32/500]
# Train Loss: 0.012078 | Val NMSE: -1.11 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.91 seconds
# Epoch [33/500]
# Train Loss: 0.012061 | Val NMSE: -1.11 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.97 seconds
# Epoch [34/500]
# Train Loss: 0.012059 | Val NMSE: -1.12 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.89 seconds
# Epoch [35/500]
# Train Loss: 0.012059 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.72 seconds
# Epoch [36/500]
# Train Loss: 0.012058 | Val NMSE: -1.12 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.13 seconds
# Epoch [37/500]
# Train Loss: 0.012050 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.42 seconds
# Epoch [38/500]
# Train Loss: 0.012051 | Val NMSE: -1.12 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.93 seconds
# Epoch [39/500]
# Train Loss: 0.012049 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 47.01 seconds
# Epoch [40/500]
# Train Loss: 0.012044 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.79 seconds
# Epoch [41/500]
# Train Loss: 0.012034 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.45 seconds
# Epoch [42/500]
# Train Loss: 0.012038 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 45.21 seconds
# Epoch [43/500]
# Train Loss: 0.012036 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 46.94 seconds
# Epoch [44/500]
# Train Loss: 0.012040 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.75 seconds
# Epoch [45/500]
# Train Loss: 0.012021 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.30 seconds
# Epoch [46/500]
# Train Loss: 0.012023 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [47/500]
# Train Loss: 0.012023 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [48/500]
# Train Loss: 0.012027 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.78 seconds
# Epoch [49/500]
# Train Loss: 0.012013 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.73 seconds
# Epoch [50/500]
# Train Loss: 0.012017 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [51/500]
# Train Loss: 0.012007 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.57 seconds
# Epoch [52/500]
# Train Loss: 0.012021 | Val NMSE: -1.12 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.09 seconds
# Epoch [53/500]
# Train Loss: 0.012007 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.50 seconds
# Epoch [54/500]
# Train Loss: 0.012011 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.48 seconds
# Epoch [55/500]
# Train Loss: 0.012012 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [56/500]
# Train Loss: 0.012017 | Val NMSE: -1.13 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.58 seconds
# Epoch [57/500]
# Train Loss: 0.012005 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.66 seconds
# Epoch [58/500]
# Train Loss: 0.011997 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.78 seconds
# Epoch [59/500]
# Train Loss: 0.012002 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [60/500]
# Train Loss: 0.011996 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [61/500]
# Train Loss: 0.011999 | Val NMSE: -1.12 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [62/500]
# Train Loss: 0.011997 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [63/500]
# Train Loss: 0.012001 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [64/500]
# Train Loss: 0.012001 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [65/500]
# Train Loss: 0.012003 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [66/500]
# Train Loss: 0.011999 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [67/500]
# Train Loss: 0.011996 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [68/500]
# Train Loss: 0.011995 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.75 seconds
# Epoch [69/500]
# Train Loss: 0.012018 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [70/500]
# Train Loss: 0.011986 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [71/500]
# Train Loss: 0.011988 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [72/500]
# Train Loss: 0.011979 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.33 seconds
# Epoch [73/500]
# Train Loss: 0.011974 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [74/500]
# Train Loss: 0.011976 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [75/500]
# Train Loss: 0.011977 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.60 seconds
# Epoch [76/500]
# Train Loss: 0.011976 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [77/500]
# Train Loss: 0.011985 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.97 seconds
# Epoch [78/500]
# Train Loss: 0.011971 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.10 seconds
# Epoch [79/500]
# Train Loss: 0.011974 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.95 seconds
# Epoch [80/500]
# Train Loss: 0.011978 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.59 seconds
# Epoch [81/500]
# Train Loss: 0.011969 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.09 seconds
# Epoch [82/500]
# Train Loss: 0.011971 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.49 seconds
# Epoch [83/500]
# Train Loss: 0.011966 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [84/500]
# Train Loss: 0.011967 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.21 seconds
# Epoch [85/500]
# Train Loss: 0.011979 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.00 seconds
# Epoch [86/500]
# Train Loss: 0.011965 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.00 seconds
# Epoch [87/500]
# Train Loss: 0.011973 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.06 seconds
# Epoch [88/500]
# Train Loss: 0.011976 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.86 seconds
# Epoch [89/500]
# Train Loss: 0.011969 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.71 seconds
# Epoch [90/500]
# Train Loss: 0.011965 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.84 seconds
# Epoch [91/500]
# Train Loss: 0.011965 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.66 seconds
# Epoch [92/500]
# Train Loss: 0.011962 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.85 seconds
# Epoch [93/500]
# Train Loss: 0.011965 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.98 seconds
# Epoch [94/500]
# Train Loss: 0.011955 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.68 seconds
# Epoch [95/500]
# Train Loss: 0.011958 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.82 seconds
# Epoch [96/500]
# Train Loss: 0.011959 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.76 seconds
# Epoch [97/500]
# Train Loss: 0.011967 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.44 seconds
# Epoch [98/500]
# Train Loss: 0.011968 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.92 seconds
# Epoch [99/500]
# Train Loss: 0.011963 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.23 seconds
# Epoch [100/500]
# Train Loss: 0.011957 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.70 seconds
# Epoch [101/500]
# Train Loss: 0.011955 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.74 seconds
# Epoch [102/500]
# Train Loss: 0.011956 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.07 seconds
# Epoch [103/500]
# Train Loss: 0.011957 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.00 seconds
# Epoch [104/500]
# Train Loss: 0.011957 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.54 seconds
# Epoch [105/500]
# Train Loss: 0.011974 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.92 seconds
# Epoch [106/500]
# Train Loss: 0.011960 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.16 seconds
# Epoch [107/500]
# Train Loss: 0.011949 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.74 seconds
# Epoch [108/500]
# Train Loss: 0.011950 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.38 seconds
# Epoch [109/500]
# Train Loss: 0.011954 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.30 seconds
# Epoch [110/500]
# Train Loss: 0.011958 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.80 seconds
# Epoch [111/500]
# Train Loss: 0.011948 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.10 seconds
# Epoch [112/500]
# Train Loss: 0.011951 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.16 seconds
# Epoch [113/500]
# Train Loss: 0.011953 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.29 seconds
# Epoch [114/500]
# Train Loss: 0.011957 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.81 seconds
# Epoch [115/500]
# Train Loss: 0.011956 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.98 seconds
# Epoch [116/500]
# Train Loss: 0.011943 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.57 seconds
# Epoch [117/500]
# Train Loss: 0.011938 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.44 seconds
# Epoch [118/500]
# Train Loss: 0.011958 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.32 seconds
# Epoch [119/500]
# Train Loss: 0.011944 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.30 seconds
# Epoch [120/500]
# Train Loss: 0.011961 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.01 seconds
# Epoch [121/500]
# Train Loss: 0.011950 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.34 seconds
# Epoch [122/500]
# Train Loss: 0.011945 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.27 seconds
# Epoch [123/500]
# Train Loss: 0.011963 | Val NMSE: -1.15 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.47 seconds
# Epoch [124/500]
# Train Loss: 0.011970 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.21 seconds
# Epoch [125/500]
# Train Loss: 0.011968 | Val NMSE: -1.14 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.82 seconds
# Epoch [126/500]
# Train Loss: 0.011966 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.95 seconds
# Epoch [127/500]
# Train Loss: 0.011947 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.58 seconds
# Epoch [128/500]
# Train Loss: 0.011946 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.27 seconds
# Epoch [129/500]
# Train Loss: 0.011939 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.96 seconds
# Epoch [130/500]
# Train Loss: 0.011939 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.62 seconds
# Epoch [131/500]
# Train Loss: 0.011945 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.82 seconds
# Epoch [132/500]
# Train Loss: 0.011943 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 44.20 seconds
# Epoch [133/500]
# Train Loss: 0.011962 | Val NMSE: -1.18 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.57 seconds
# Epoch [134/500]
# Train Loss: 0.011956 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.33 seconds
# Epoch [135/500]
# Train Loss: 0.011948 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.60 seconds
# Epoch [136/500]
# Train Loss: 0.011937 | Val NMSE: -1.17 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [137/500]
# Train Loss: 0.011956 | Val NMSE: -1.16 dB
# Current LR: 0.001
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [138/500]
# Train Loss: 0.011959 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.12 seconds
# Epoch [139/500]
# Train Loss: 0.011924 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.61 seconds
# Epoch [140/500]
# Train Loss: 0.011916 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.56 seconds
# Epoch [141/500]
# Train Loss: 0.011915 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.38 seconds
# Epoch [142/500]
# Train Loss: 0.011925 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.58 seconds
# Epoch [143/500]
# Train Loss: 0.011912 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.33 seconds
# Epoch [144/500]
# Train Loss: 0.011916 | Val NMSE: -1.19 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.02 seconds
# Epoch [145/500]
# Train Loss: 0.011918 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.29 seconds
# Epoch [146/500]
# Train Loss: 0.011923 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.08 seconds
# Epoch [147/500]
# Train Loss: 0.011921 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.10 seconds
# Epoch [148/500]
# Train Loss: 0.011932 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.09 seconds
# Epoch [149/500]
# Train Loss: 0.011930 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.96 seconds
# Epoch [150/500]
# Train Loss: 0.011926 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.28 seconds
# Epoch [151/500]
# Train Loss: 0.011929 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.95 seconds
# Epoch [152/500]
# Train Loss: 0.011915 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.95 seconds
# Epoch [153/500]
# Train Loss: 0.011921 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [154/500]
# Train Loss: 0.011914 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.52 seconds
# Epoch [155/500]
# Train Loss: 0.011927 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.12 seconds
# Epoch [156/500]
# Train Loss: 0.011921 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.11 seconds
# Epoch [157/500]
# Train Loss: 0.011914 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.16 seconds
# Epoch [158/500]
# Train Loss: 0.011917 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.00 seconds
# Epoch [159/500]
# Train Loss: 0.011912 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.43 seconds
# Epoch [160/500]
# Train Loss: 0.011907 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [161/500]
# Train Loss: 0.011906 | Val NMSE: -1.19 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.90 seconds
# Epoch [162/500]
# Train Loss: 0.011903 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.89 seconds
# Epoch [163/500]
# Train Loss: 0.011908 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.13 seconds
# Epoch [164/500]
# Train Loss: 0.011913 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.23 seconds
# Epoch [165/500]
# Train Loss: 0.011915 | Val NMSE: -1.17 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.08 seconds
# Epoch [166/500]
# Train Loss: 0.011911 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 44.12 seconds
# Epoch [167/500]
# Train Loss: 0.011909 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 44.35 seconds
# Epoch [168/500]
# Train Loss: 0.011912 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.98 seconds
# Epoch [169/500]
# Train Loss: 0.011920 | Val NMSE: -1.19 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.61 seconds
# Epoch [170/500]
# Train Loss: 0.011907 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.51 seconds
# Epoch [171/500]
# Train Loss: 0.011920 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.31 seconds
# Epoch [172/500]
# Train Loss: 0.011911 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.55 seconds
# Epoch [173/500]
# Train Loss: 0.011914 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.74 seconds
# Epoch [174/500]
# Train Loss: 0.011905 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 44.08 seconds
# Epoch [175/500]
# Train Loss: 0.011902 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 44.04 seconds
# Epoch [176/500]
# Train Loss: 0.011911 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.89 seconds
# Epoch [177/500]
# Train Loss: 0.011906 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.87 seconds
# Epoch [178/500]
# Train Loss: 0.011906 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.85 seconds
# Epoch [179/500]
# Train Loss: 0.011905 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.31 seconds
# Epoch [180/500]
# Train Loss: 0.011914 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.07 seconds
# Epoch [181/500]
# Train Loss: 0.011915 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 43.27 seconds
# Epoch [182/500]
# Train Loss: 0.011916 | Val NMSE: -1.18 dB
# Current LR: 0.0005
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [183/500]
# Train Loss: 0.011920 | Val NMSE: -1.17 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.94 seconds
# Epoch [184/500]
# Train Loss: 0.011903 | Val NMSE: -1.17 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.75 seconds
# Epoch [185/500]
# Train Loss: 0.011903 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.96 seconds
# Epoch [186/500]
# Train Loss: 0.011919 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.99 seconds
# Epoch [187/500]
# Train Loss: 0.011910 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.75 seconds
# Epoch [188/500]
# Train Loss: 0.011908 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 43.15 seconds
# Epoch [189/500]
# Train Loss: 0.011906 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 43.10 seconds
# Epoch [190/500]
# Train Loss: 0.011900 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.87 seconds
# Epoch [191/500]
# Train Loss: 0.011900 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.97 seconds
# Epoch [192/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.93 seconds
# Epoch [193/500]
# Train Loss: 0.011896 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.95 seconds
# Epoch [194/500]
# Train Loss: 0.011901 | Val NMSE: -1.17 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 43.01 seconds
# Epoch [195/500]
# Train Loss: 0.011895 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.97 seconds
# Epoch [196/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.96 seconds
# Epoch [197/500]
# Train Loss: 0.011907 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [198/500]
# Train Loss: 0.011901 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.93 seconds
# Epoch [199/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.91 seconds
# Epoch [200/500]
# Train Loss: 0.011899 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.90 seconds
# Epoch [201/500]
# Train Loss: 0.011896 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [202/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [203/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 43.01 seconds
# Epoch [204/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.86 seconds
# Epoch [205/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.98 seconds
# Epoch [206/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.86 seconds
# Epoch [207/500]
# Train Loss: 0.011899 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.99 seconds
# Epoch [208/500]
# Train Loss: 0.011889 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.94 seconds
# Epoch [209/500]
# Train Loss: 0.011894 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.82 seconds
# Epoch [210/500]
# Train Loss: 0.011891 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.98 seconds
# Epoch [211/500]
# Train Loss: 0.011895 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.91 seconds
# Epoch [212/500]
# Train Loss: 0.011900 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [213/500]
# Train Loss: 0.011891 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.84 seconds
# Epoch [214/500]
# Train Loss: 0.011896 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.81 seconds
# Epoch [215/500]
# Train Loss: 0.011901 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [216/500]
# Train Loss: 0.011903 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [217/500]
# Train Loss: 0.011902 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.92 seconds
# Epoch [218/500]
# Train Loss: 0.011889 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.80 seconds
# Epoch [219/500]
# Train Loss: 0.011890 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.87 seconds
# Epoch [220/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.18 seconds
# Epoch [221/500]
# Train Loss: 0.011890 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [222/500]
# Train Loss: 0.011901 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [223/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.28 seconds
# Epoch [224/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [225/500]
# Train Loss: 0.011892 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.28 seconds
# Epoch [226/500]
# Train Loss: 0.011895 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [227/500]
# Train Loss: 0.011889 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.64 seconds
# Epoch [228/500]
# Train Loss: 0.011899 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.43 seconds
# Epoch [229/500]
# Train Loss: 0.011895 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [230/500]
# Train Loss: 0.011886 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [231/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [232/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.82 seconds
# Epoch [233/500]
# Train Loss: 0.011899 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.84 seconds
# Epoch [234/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [235/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.43 seconds
# Epoch [236/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.42 seconds
# Epoch [237/500]
# Train Loss: 0.011888 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.57 seconds
# Epoch [238/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.37 seconds
# Epoch [239/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.57 seconds
# Epoch [240/500]
# Train Loss: 0.011894 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.45 seconds
# Epoch [241/500]
# Train Loss: 0.011901 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [242/500]
# Train Loss: 0.011902 | Val NMSE: -1.18 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.18 seconds
# Epoch [243/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.45 seconds
# Epoch [244/500]
# Train Loss: 0.011898 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.21 seconds
# Epoch [245/500]
# Train Loss: 0.011897 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.39 seconds
# Epoch [246/500]
# Train Loss: 0.011891 | Val NMSE: -1.20 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [247/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.58 seconds
# Epoch [248/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [249/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [250/500]
# Train Loss: 0.011889 | Val NMSE: -1.19 dB
# Current LR: 0.00025
# ------------------------------
# Epoch took 42.44 seconds
# Epoch [251/500]
# Train Loss: 0.011894 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 43.03 seconds
# Epoch [252/500]
# Train Loss: 0.011895 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.75 seconds
# Epoch [253/500]
# Train Loss: 0.011886 | Val NMSE: -1.18 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.38 seconds
# Epoch [254/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [255/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [256/500]
# Train Loss: 0.011891 | Val NMSE: -1.20 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.32 seconds
# Epoch [257/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.07 seconds
# Epoch [258/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [259/500]
# Train Loss: 0.011886 | Val NMSE: -1.18 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.52 seconds
# Epoch [260/500]
# Train Loss: 0.011890 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [261/500]
# Train Loss: 0.011889 | Val NMSE: -1.20 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.57 seconds
# Epoch [262/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.46 seconds
# Epoch [263/500]
# Train Loss: 0.011894 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.64 seconds
# Epoch [264/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [265/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.64 seconds
# Epoch [266/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [267/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.45 seconds
# Epoch [268/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.60 seconds
# Epoch [269/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [270/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.33 seconds
# Epoch [271/500]
# Train Loss: 0.011894 | Val NMSE: -1.19 dB
# Current LR: 0.000125
# ------------------------------
# Epoch took 42.41 seconds
# Epoch [272/500]
# Train Loss: 0.011889 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.31 seconds
# Epoch [273/500]
# Train Loss: 0.011889 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.77 seconds
# Epoch [274/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [275/500]
# Train Loss: 0.011890 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.41 seconds
# Epoch [276/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [277/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [278/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [279/500]
# Train Loss: 0.011889 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.52 seconds
# Epoch [280/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [281/500]
# Train Loss: 0.011891 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.91 seconds
# Epoch [282/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [283/500]
# Train Loss: 0.011890 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [284/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.99 seconds
# Epoch [285/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [286/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.47 seconds
# Epoch [287/500]
# Train Loss: 0.011886 | Val NMSE: -1.18 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.39 seconds
# Epoch [288/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.43 seconds
# Epoch [289/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.78 seconds
# Epoch [290/500]
# Train Loss: 0.011889 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [291/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [292/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.31 seconds
# Epoch [293/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [294/500]
# Train Loss: 0.011877 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.74 seconds
# Epoch [295/500]
# Train Loss: 0.011891 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [296/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.73 seconds
# Epoch [297/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [298/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.39 seconds
# Epoch [299/500]
# Train Loss: 0.011885 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [300/500]
# Train Loss: 0.011888 | Val NMSE: -1.18 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [301/500]
# Train Loss: 0.011890 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [302/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.80 seconds
# Epoch [303/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [304/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.22 seconds
# Epoch [305/500]
# Train Loss: 0.011877 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.46 seconds
# Epoch [306/500]
# Train Loss: 0.011888 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.46 seconds
# Epoch [307/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.50 seconds
# Epoch [308/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.47 seconds
# Epoch [309/500]
# Train Loss: 0.011893 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [310/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [311/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.34 seconds
# Epoch [312/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.48 seconds
# Epoch [313/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.79 seconds
# Epoch [314/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [315/500]
# Train Loss: 0.011881 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.90 seconds
# Epoch [316/500]
# Train Loss: 0.011885 | Val NMSE: -1.18 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.66 seconds
# Epoch [317/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [318/500]
# Train Loss: 0.011882 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.75 seconds
# Epoch [319/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.58 seconds
# Epoch [320/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.79 seconds
# Epoch [321/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.29 seconds
# Epoch [322/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [323/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.87 seconds
# Epoch [324/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.41 seconds
# Epoch [325/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [326/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.44 seconds
# Epoch [327/500]
# Train Loss: 0.011879 | Val NMSE: -1.18 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [328/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.84 seconds
# Epoch [329/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [330/500]
# Train Loss: 0.011887 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [331/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.42 seconds
# Epoch [332/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [333/500]
# Train Loss: 0.011890 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [334/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.42 seconds
# Epoch [335/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.73 seconds
# Epoch [336/500]
# Train Loss: 0.011884 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.90 seconds
# Epoch [337/500]
# Train Loss: 0.011884 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.39 seconds
# Epoch [338/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [339/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [340/500]
# Train Loss: 0.011883 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [341/500]
# Train Loss: 0.011880 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [342/500]
# Train Loss: 0.011877 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [343/500]
# Train Loss: 0.011876 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [344/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [345/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.57 seconds
# Epoch [346/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [347/500]
# Train Loss: 0.011881 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.60 seconds
# Epoch [348/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [349/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [350/500]
# Train Loss: 0.011877 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [351/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.51 seconds
# Epoch [352/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.30 seconds
# Epoch [353/500]
# Train Loss: 0.011889 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.52 seconds
# Epoch [354/500]
# Train Loss: 0.011892 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [355/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.72 seconds
# Epoch [356/500]
# Train Loss: 0.011881 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.64 seconds
# Epoch [357/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [358/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.78 seconds
# Epoch [359/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [360/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [361/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [362/500]
# Train Loss: 0.011879 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [363/500]
# ...
# Epoch took 42.70 seconds
# Epoch [381/500]
# Train Loss: 0.011883 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.45 seconds
# Epoch [382/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [383/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.57 seconds
# Epoch [384/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.38 seconds
# Epoch [385/500]
# Train Loss: 0.011877 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.01 seconds
# Epoch [386/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [387/500]
# Train Loss: 0.011876 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [388/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.43 seconds
# Epoch [389/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [390/500]
# Train Loss: 0.011879 | Val NMSE: -1.18 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.44 seconds
# Epoch [391/500]
# Train Loss: 0.011882 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.52 seconds
# Epoch [392/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.60 seconds
# Epoch [393/500]
# Train Loss: 0.011875 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [394/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.78 seconds
# Epoch [395/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [396/500]
# Train Loss: 0.011877 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [397/500]
# Train Loss: 0.011882 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [398/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [399/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [400/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.44 seconds
# Epoch [401/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [402/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [403/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [404/500]
# Train Loss: 0.011887 | Val NMSE: -1.18 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [405/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.44 seconds
# Epoch [406/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [407/500]
# Train Loss: 0.011874 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [408/500]
# Train Loss: 0.011887 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.82 seconds
# Epoch [409/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [410/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.60 seconds
# Epoch [411/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.91 seconds
# Epoch [412/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [413/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.52 seconds
# Epoch [414/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.72 seconds
# Epoch [415/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.54 seconds
# Epoch [416/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [417/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.73 seconds
# Epoch [418/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [419/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.27 seconds
# Epoch [420/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.34 seconds
# Epoch [421/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.43 seconds
# Epoch [422/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.81 seconds
# Epoch [423/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [424/500]
# Train Loss: 0.011888 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [425/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [426/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [427/500]
# Train Loss: 0.011874 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.81 seconds
# Epoch [428/500]
# Train Loss: 0.011885 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [429/500]
# Train Loss: 0.011874 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [430/500]
# Train Loss: 0.011879 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.38 seconds
# Epoch [431/500]
# Train Loss: 0.011875 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.84 seconds
# Epoch [432/500]
# Train Loss: 0.011875 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [433/500]
# Train Loss: 0.011876 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [434/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [435/500]
# Train Loss: 0.011878 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.48 seconds
# Epoch [436/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.65 seconds
# Epoch [437/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.72 seconds
# Epoch [438/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [439/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.66 seconds
# Epoch [440/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.84 seconds
# Epoch [441/500]
# Train Loss: 0.011876 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.73 seconds
# Epoch [442/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.04 seconds
# Epoch [443/500]
# Train Loss: 0.011885 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [444/500]
# Train Loss: 0.011884 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.80 seconds
# Epoch [445/500]
# Train Loss: 0.011876 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.45 seconds
# Epoch [446/500]
# Train Loss: 0.011883 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.53 seconds
# Epoch [447/500]
# Train Loss: 0.011879 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.46 seconds
# Epoch [448/500]
# Train Loss: 0.011882 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [449/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.46 seconds
# Epoch [450/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.64 seconds
# Epoch [451/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [452/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [453/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.74 seconds
# Epoch [454/500]
# Train Loss: 0.011885 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [455/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.66 seconds
# Epoch [456/500]
# Train Loss: 0.011879 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.55 seconds
# Epoch [457/500]
# Train Loss: 0.011876 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [458/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.50 seconds
# Epoch [459/500]
# Train Loss: 0.011877 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [460/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [461/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.74 seconds
# Epoch [462/500]
# Train Loss: 0.011883 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [463/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [464/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.72 seconds
# Epoch [465/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.84 seconds
# Epoch [466/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.72 seconds
# Epoch [467/500]
# Train Loss: 0.011873 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.62 seconds
# Epoch [468/500]
# Train Loss: 0.011875 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.70 seconds
# Epoch [469/500]
# Train Loss: 0.011880 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.68 seconds
# Epoch [470/500]
# Train Loss: 0.011890 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.44 seconds
# Epoch [471/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.69 seconds
# Epoch [472/500]
# Train Loss: 0.011878 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.72 seconds
# Epoch [473/500]
# Train Loss: 0.011876 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [474/500]
# Train Loss: 0.011875 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.33 seconds
# Epoch [475/500]
# Train Loss: 0.011886 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [476/500]
# Train Loss: 0.011873 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.66 seconds
# Epoch [477/500]
# Train Loss: 0.011877 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.73 seconds
# Epoch [478/500]
# Train Loss: 0.011876 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.49 seconds
# Epoch [479/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.27 seconds
# Epoch [480/500]
# Train Loss: 0.011885 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.59 seconds
# Epoch [481/500]
# Train Loss: 0.011881 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.61 seconds
# Epoch [482/500]
# Train Loss: 0.011884 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.34 seconds
# Epoch [483/500]
# Train Loss: 0.011878 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.82 seconds
# Epoch [484/500]
# Train Loss: 0.011881 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.76 seconds
# Epoch [485/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.58 seconds
# Epoch [486/500]
# Train Loss: 0.011882 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [487/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.64 seconds
# Epoch [488/500]
# Train Loss: 0.011881 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.11 seconds
# Epoch [489/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.67 seconds
# Epoch [490/500]
# Train Loss: 0.011872 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.87 seconds
# Epoch [491/500]
# Train Loss: 0.011879 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.94 seconds
# Epoch [492/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.50 seconds
# Epoch [493/500]
# Train Loss: 0.011879 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [494/500]
# Train Loss: 0.011882 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.23 seconds
# Epoch [495/500]
# Train Loss: 0.011873 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.56 seconds
# Epoch [496/500]
# Train Loss: 0.011881 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.63 seconds
# Epoch [497/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.86 seconds
# Epoch [498/500]
# Train Loss: 0.011879 | Val NMSE: -1.20 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.71 seconds
# Epoch [499/500]
# Train Loss: 0.011883 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.66 seconds
# Epoch [500/500]
# Train Loss: 0.011875 | Val NMSE: -1.19 dB
# Current LR: 0.0001
# ------------------------------
# Epoch took 42.85 seconds

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

def evaluate_performance_curve(data, collater, snr_points=None):
    """
    Evaluates the trained model across a range of fixed SNRs.
    snr_points: list of SNRs in dB to test (e.g., [-10, -5, 0, 5, 10])
    """
    if snr_points is None:
        snr_points = np.linspace(-10, 10, 9) # Matches paper evaluation range [cite: 445, 550]
    
    results = {}
    
    # Set models to evaluation mode
    atn.eval(); encoder.eval(); decoder.eval(); stn.eval()
    
    print("Starting SNR Evaluation...")
    with torch.no_grad():
        for test_snr in snr_points:
            total_nmse = 0.0
            # Use the full test partition (50,000 samples)
            # 50,000 / batch_size(200) = 250 steps
            num_test_steps = 50000 // collater.batch_size 
            
            for _ in range(num_test_steps):
                # 1. Get test data
                x_test, _ = collater(data, mode="test")
                x_test = x_test.to(device)
                
                # 2. Fix the SNR for this specific test point
                # Every sample in the batch gets the same test_snr
                snr_fixed = torch.full((collater.batch_size, 1), test_snr, device=device).float()
                
                # 3. Forward Pass (End-to-End)
                t = atn(x_test, snr_fixed)
                c = encoder(t, snr_fixed)
                s = enc_to_complex_and_normalize(c)
                s_hat = channel_sim(s, snr_fixed)
                c_hat = c2r(s_hat)
                t_hat = decoder(c_hat, snr_fixed)
                x_hat = stn(t_hat, snr_fixed)
                
                # 4. Calculate NMSE [cite: 439, 440]
                total_nmse += calculate_nmse(x_test, x_hat).item()
            
            avg_nmse = total_nmse / num_test_steps
            results[test_snr] = avg_nmse
            print(f"SNR: {test_snr:>5} dB | NMSE: {avg_nmse:.2f} dB")
            
    return results

# --- Run Evaluation and Plot ---
snr_range = [-10, -7.5, -5, -2.5, 0, 2.5, 5, 7.5, 10]
perf_data = evaluate_performance_curve(data, collater, snr_range)

plt.figure(figsize=(8, 6))
plt.plot(list(perf_data.keys()), list(perf_data.values()), 'ro-', label='ADJSCC-CSINet+')
plt.xlabel('SNR_test (dB)')
plt.ylabel('NMSE (dB)')
plt.title('CSI Reconstruction Performance (Feedback Bandwidth k=16)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Starting SNR Evaluation...
# SNR:   -10 dB | NMSE: -0.58 dB
# SNR:  -7.5 dB | NMSE: -0.83 dB
# SNR:    -5 dB | NMSE: -1.02 dB
# SNR:  -2.5 dB | NMSE: -1.17 dB
# SNR:     0 dB | NMSE: -1.24 dB
# SNR:   2.5 dB | NMSE: -1.21 dB
# SNR:     5 dB | NMSE: -1.15 dB
# SNR:   7.5 dB | NMSE: -1.01 dB
# SNR:    10 dB | NMSE: -0.82 dB
